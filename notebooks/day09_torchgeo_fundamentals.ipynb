# %%
# Day 09 - TorchGeo Fundamentals

import torch

print("PyTorch Version:", torch.__version__)
# Out:
# PyTorch Version: 2.11.0+cpu

# %%
import torchgeo

print("TorchGeo Version:", torchgeo.__version__)
# Out:
# TorchGeo Version: 0.9.0

# %%
from torchgeo.datasets import RasterDataset

print(RasterDataset)
# Out:
# <class 'torchgeo.datasets.geo.RasterDataset'>

# %%
from torchgeo.datasets import GeoDataset

print(GeoDataset)
# Out:
# <class 'torchgeo.datasets.geo.GeoDataset'>

# %%
from torchgeo.samplers import RandomGeoSampler
from torchgeo.samplers import GridGeoSampler

print("RandomGeoSampler:", RandomGeoSampler)
print("GridGeoSampler:", GridGeoSampler)
# Out:
# RandomGeoSampler: <class 'torchgeo.samplers.single.RandomGeoSampler'>
# GridGeoSampler: <class 'torchgeo.samplers.single.GridGeoSampler'>

# %%
torchgeo_components = {
    "GeoDataset": "Base class for geospatial datasets",
    "RasterDataset": "Satellite imagery",
    "VectorDataset": "Roads, buildings, polygons",
    "IntersectionDataset": "Combines imagery and labels",
    "RandomGeoSampler": "Training patch extraction",
    "GridGeoSampler": "Inference patch extraction"
}

for k, v in torchgeo_components.items():
    print(f"{k}: {v}")
# Out:
# GeoDataset: Base class for geospatial datasets
# RasterDataset: Satellite imagery
# VectorDataset: Roads, buildings, polygons
# IntersectionDataset: Combines imagery and labels
# RandomGeoSampler: Training patch extraction
# GridGeoSampler: Inference patch extraction

# %%
workflow = """
Sentinel-2 Images
        ↓
RasterDataset
        ↓
RandomGeoSampler
        ↓
DataLoader
        ↓
Model
        ↓
Urban Expansion Detection
        ↓
Vegetation Loss Detection
"""

print(workflow)
# Out:
# Sentinel-2 Images
#         ↓
# RasterDataset
#         ↓
# RandomGeoSampler
#         ↓
# DataLoader
#         ↓
# Model
#         ↓
# Urban Expansion Detection
#         ↓
# Vegetation Loss Detection

# %%
questions = [
    "What is TorchGeo?",
    "What is RasterDataset?",
    "What is VectorDataset?",
    "Difference between RandomGeoSampler and GridGeoSampler?",
    "How will TorchGeo be used in GeoSentinel AI?"
]

for i, q in enumerate(questions, 1):
    print(f"{i}. {q}")
# Out:
# 1. What is TorchGeo?
# 2. What is RasterDataset?
# 3. What is VectorDataset?
# 4. Difference between RandomGeoSampler and GridGeoSampler?
# 5. How will TorchGeo be used in GeoSentinel AI?
