# %%
# Day 10 - TorchGeo Datasets Deep Dive

import torch

print("PyTorch Version:", torch.__version__)
# Out:
# PyTorch Version: 2.11.0+cpu

# %%
import torchgeo

print("TorchGeo Version:", torchgeo.__version__)
# Out:
# TorchGeo Version: 0.9.0

# %%
from torchgeo.datasets import GeoDataset

print(GeoDataset)
# Out:
# <class 'torchgeo.datasets.geo.GeoDataset'>

# %%
from torchgeo.datasets import RasterDataset

print(RasterDataset)
# Out:
# <class 'torchgeo.datasets.geo.RasterDataset'>

# %%
sentinel2_bands = {
    "B2": "Blue",
    "B3": "Green",
    "B4": "Red",
    "B8": "NIR",
    "B11": "SWIR",
    "B12": "SWIR"
}

for band, meaning in sentinel2_bands.items():
    print(f"{band} -> {meaning}")
# Out:
# B2 -> Blue
# B3 -> Green
# B4 -> Red
# B8 -> NIR
# B11 -> SWIR
# B12 -> SWIR

# %%
metadata = [
    "CRS",
    "Resolution",
    "Transform",
    "Bounds",
    "Band Information"
]

for item in metadata:
    print(item)
# Out:
# CRS
# Resolution
# Transform
# Bounds
# Band Information

# %%
metadata = [
    "CRS",
    "Resolution",
    "Transform",
    "Bounds",
    "Band Information"
]

for item in metadata:
    print(item)
# Out:
# CRS
# Resolution
# Transform
# Bounds
# Band Information
