# %%
print("""
Segmentation Architectures

1. FCN
2. U-Net
3. DeepLabV3

Goal:

Image
 ↓
Pixel-wise Classification
 ↓
Segmentation Mask
""")
# Out:
# Segmentation Architectures
#
# 1. FCN
# 2. U-Net
# 3. DeepLabV3
#
# Goal:
#
# Image
#  ↓
# Pixel-wise Classification
#  ↓
# Segmentation Mask

# %%
print("""
FCN

Fully Convolutional Network

CNN
 ↓
Feature Maps
 ↓
Upsampling
 ↓
Mask

First major segmentation architecture.
""")
# Out:
# FCN
#
# Fully Convolutional Network
#
# CNN
#  ↓
# Feature Maps
#  ↓
# Upsampling
#  ↓
# Mask
#
# First major segmentation architecture.

# %%
print("""
U-Net

Encoder
 ↓
Bottleneck
 ↓
Decoder

Skip Connections

Most popular architecture
in remote sensing.
""")
# Out:
# U-Net
#
# Encoder
#  ↓
# Bottleneck
#  ↓
# Decoder
#
# Skip Connections
#
# Most popular architecture
# in remote sensing.

# %%
print("""
Input
  ↓
Encoder

256
 ↓
128
 ↓
64
 ↓
32

Bottleneck

32

Decoder

32
 ↑
64
 ↑
128
 ↑
256

Output Mask
""")
# Out:
# Input
#   ↓
# Encoder
#
# 256
#  ↓
# 128
#  ↓
# 64
#  ↓
# 32
#
# Bottleneck
#
# 32
#
# Decoder
#
# 32
#  ↑
# 64
#  ↑
# 128
#  ↑
# 256
#
# Output Mask

# %%
print("""
Skip Connections

Encoder Features
        ↓
        ↓
Decoder Features

Helps recover
spatial information.
""")
# Out:
# Skip Connections
#
# Encoder Features
#         ↓
#         ↓
# Decoder Features
#
# Helps recover
# spatial information.

# %%
advantages = [

    "Preserves spatial details",

    "Works with small datasets",

    "Easy to train",

    "Popular in remote sensing",

    "Popular in medical imaging"
]

for item in advantages:

    print(
        "-",
        item
    )
# Out:
# - Preserves spatial details
# - Works with small datasets
# - Easy to train
# - Popular in remote sensing
# - Popular in medical imaging

# %%
print("""
DeepLabV3

Encoder
      ↓
Atrous Convolution
      ↓
Multi-scale Features
      ↓
Prediction

Excellent for large objects.
""")
# Out:
# DeepLabV3
#
# Encoder
#       ↓
# Atrous Convolution
#       ↓
# Multi-scale Features
#       ↓
# Prediction
#
# Excellent for large objects.

# %%
print("""
Atrous Convolution

Normal:

X X X

Atrous:

X . X . X

Larger receptive field
without increasing parameters.
""")
# Out:
# Atrous Convolution
#
# Normal:
#
# X X X
#
# Atrous:
#
# X . X . X
#
# Larger receptive field
# without increasing parameters.

# %%
architectures = {

    "FCN":
        "Baseline",

    "U-Net":
        "Most Popular",

    "DeepLabV3":
        "State of the Art"
}

for k, v in architectures.items():

    print(
        f"{k}: {v}"
    )
# Out:
# FCN: Baseline
# U-Net: Most Popular
# DeepLabV3: State of the Art

# %%
print("""
GeoSentinel Model Plan

Baseline:
U-Net

Advanced:
DeepLabV3

Compare:

IoU
Dice Score
Inference Speed
""")
# Out:
# GeoSentinel Model Plan
#
# Baseline:
# U-Net
#
# Advanced:
# DeepLabV3
#
# Compare:
#
# IoU
# Dice Score
# Inference Speed

# %%
print("""
GeoSentinel

Sentinel-2 Patch
         ↓
U-Net
         ↓
Vegetation Mask

and

Urban Mask
         ↓
Change Detection
""")
# Out:
# GeoSentinel
#
# Sentinel-2 Patch
#          ↓
# U-Net
#          ↓
# Vegetation Mask
#
# and
#
# Urban Mask
#          ↓
# Change Detection

# %%
print("""
Day 19 Summary

FCN
 ↓
U-Net
 ↓
DeepLabV3

Tomorrow:

Build First GeoSentinel Dataset
""")
# Out:
# Day 19 Summary
#
# FCN
#  ↓
# U-Net
#  ↓
# DeepLabV3
#
# Tomorrow:
#
# Build First GeoSentinel Dataset
