# %%
classes = {

    0: "Background",

    1: "Vegetation",

    2: "Urban",

    3: "Water"
}

for idx, name in classes.items():

    print(
        f"{idx} -> {name}"
    )
# Out:
# 0 -> Background
# 1 -> Vegetation
# 2 -> Urban
# 3 -> Water

# %%
sample = {

    "image": "(4,256,256)",

    "mask": "(256,256)",

    "year": "2026",

    "location": "Hyderabad"
}

for k, v in sample.items():

    print(
        k,
        "=>",
        v
    )
# Out:
# image => (4,256,256)
# mask => (256,256)
# year => 2026
# location => Hyderabad

# %%
bands = [

    "B02 Blue",

    "B03 Green",

    "B04 Red",

    "B08 NIR"
]

for band in bands:

    print(band)
# Out:
# B02 Blue
# B03 Green
# B04 Red
# B08 NIR

# %%
indices = [

    "NDVI",

    "NDBI",

    "EVI",

    "MSAVI"
]

for idx in indices:

    print(idx)
# Out:
# NDVI
# NDBI
# EVI
# MSAVI

# %%
index_usage = {

    "NDVI":
        "Vegetation Detection",

    "NDBI":
        "Urban Detection",

    "EVI":
        "Dense Vegetation Analysis",

    "MSAVI":
        "Sparse Vegetation Analysis"
}

for k, v in index_usage.items():

    print(
        f"{k}: {v}"
    )
# Out:
# NDVI: Vegetation Detection
# NDBI: Urban Detection
# EVI: Dense Vegetation Analysis
# MSAVI: Sparse Vegetation Analysis

# %%
print("""
GeoSentinel Dataset Pipeline

Sentinel-2
      ↓
Bands
      ↓
Indices
      ↓
Patch Extraction
      ↓
Training Samples
      ↓
Segmentation Model
""")
# Out:
# GeoSentinel Dataset Pipeline
#
# Sentinel-2
#       ↓
# Bands
#       ↓
# Indices
#       ↓
# Patch Extraction
#       ↓
# Training Samples
#       ↓
# Segmentation Model

# %%
patch_size = 256

print(
    f"Patch Size = {patch_size}"
)
# Out:
# Patch Size = 256

# %%
scene_size = 10980

patches = (

    scene_size // patch_size

) ** 2

print(
    "Approx Patches:",
    patches
)
# Out:
# Approx Patches: 1764

# %%
print("""
Input:

RGB + NIR

Output:

Segmentation Mask

Classes:

Vegetation
Urban
Water
Background
""")
# Out:
# Input:
#
# RGB + NIR
#
# Output:
#
# Segmentation Mask
#
# Classes:
#
# Vegetation
# Urban
# Water
# Background

# %%
print("""
Phase 1

Vegetation Segmentation

Urban Segmentation

Water Segmentation

Phase 2

Change Detection
""")
# Out:
# Phase 1
#
# Vegetation Segmentation
#
# Urban Segmentation
#
# Water Segmentation
#
# Phase 2
#
# Change Detection

# %%
print("""
Patch
 ↓
U-Net
 ↓
Prediction Mask
 ↓
IoU
 ↓
Model Improvement
""")
# Out:
# Patch
#  ↓
# U-Net
#  ↓
# Prediction Mask
#  ↓
# IoU
#  ↓
# Model Improvement

# %%
print("""
Day 20

First GeoSentinel Dataset Design Completed
""")
# Out:
# Day 20
#
# First GeoSentinel Dataset Design Completed
